# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# This is a custom matplotlib style that I use for most of my charts
# plt.style.use('tableau10.mplstyle')

child_data = pd.read_csv('abb.csv')
child_data
# Out:
#             Data Source World Development Indicators        2008        2009  \
# 0           Afghanistan                          AFG   150000000   344000000
# 1                Angola                          AGO    29000000    20000000
# 2               Albania                          ALB
# 3            Arab World                          ARB  4158000000  4053000000
# 4  United Arab Emirates                          ARE   753000000   561000000
# 5             Argentina                          ARG    23000000    11000000
# 6               Armenia                          ARM                46000000
#
#          2010        2011        2012        2013        2014        2015  \
# 0   377000000   660000000   521000000   235000000   288000000   116000000
# 1                                        31000000     2000000    47000000
# 2                            15000000     7000000     7000000     7000000
# 3  5258000000  7420000000  6029000000  6902000000  7396000000  9828000000
# 4   607000000  1200000000  1119000000  2275000000   791000000  1266000000
# 5    11000000    15000000     3000000    12000000     7000000    21000000
# 6    52000000     5000000                16000000
#
#           2016         2017         2018
# 0    176000000    284000000    240000000
# 1    142000000    108000000     75000000
# 2                   4000000      1000000
# 3  12658000000  12159000000  10693000000
# 4   1193000000   1074000000   1101000000
# 5     17000000     49000000     42000000
# 6    110000000     18000000

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(111)

for (i, row) in child_data.iterrows():
    plt.bar([i], [row['2008']],
            color=['#CC6699'], width=0.8, align='center', edgecolor='none')
    
#plt.xlim(-0.6, 20.6)
#plt.ylim(-12.1e6, 12.1e6)
plt.xticks(np.arange(0,8), child_data['country'], fontsize=11)
#plt.grid(False, axis='x')plt.xticks(np.array([8,7,6]), child_data['Data Source'], fontsize=11)
#plt.yticks(np.arange(-12e6, 13e6, 2e6),
#           ['{}m'.format(int(abs(x) / 1e6)) if x != 0 else 0 for x in np.arange(-12e6, 13e6, 2e6)])
plt.xlabel('')
plt.ylabel('')


plt.savefig('pop_pyramid_rotated.pdf')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-f7656fa34906> in <module>
#       8 #plt.xlim(-0.6, 20.6)
#       9 #plt.ylim(-12.1e6, 12.1e6)
# ---> 10 plt.xticks(np.arange(0,8), child_data['country'], fontsize=11)
#      11 #plt.grid(False, axis='x')plt.xticks(np.array([8,7,6]), child_data['Data Source'], fontsize=11)
#      12 #plt.yticks(np.arange(-12e6, 13e6, 2e6),
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'

# %%
plt.plot(x,y, 'ro')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-ef198a470fa9> in <module>
# ----> 1 plt.plot(x,y, 'ro')
#
# NameError: name 'x' is not defined
